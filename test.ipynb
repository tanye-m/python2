# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("metabolites.csv")                  
df
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
df = df.groupby("genus").mean()
df
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
sns.heatmap(df)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_iter = map(lambda x: x % 3 == 0, [1, 2, 3, 4, 5, 6])

# %%
list(my_iter)
# Out:
# [False, False, True, False, False, True]

# %%
while True:
    next(my_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-7-fb9cec301e32> in <module>
#       1 while True:
# ----> 2     next(my_iter)
#
# StopIteration:

# %%
my_iter = map(lambda x: x % 3 == 0, [1, 2, 3, 4, 5, 6])
while True:
    try:
        print(next(my_iter))
    except StopIteration:
        break
# Out:
# False
# False
# True
# False
# False
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import requests

# %%
list = [17, 45, 999, 1883]

# %%
for i in list:
    print('Number:', i)
    url1 = "https://numbersapi.p.rapidapi.com/{}/math".format(i)
    url2 = "https://numbersapi.p.rapidapi.com/{}/year".format(i)

    querystring = {"fragment":"true","notfound":"floor","json":"true"}

    headers = {
    'x-rapidapi-host': "numbersapi.p.rapidapi.com",
    'x-rapidapi-key': "77df2ba9f2msha236939499d830ap157f08jsn9aa5cc0ca02a"
    }


    response1 = requests.request("GET", url1, headers=headers, params=querystring)
    response2 = requests.request("GET", url2, headers=headers, params=querystring)

    print(response1.json()['type'], ': ', response1.json()['text'], sep = '')
    print(response2.json()['type'], ': ', response2.json()['text'], sep = '')
# Out:
# Number: 17
# math: either 16 or 18 unit squares can be formed into rectangles with perimeter equal to the area; and there are no other natural numbers with this property
# year: Cappadocia (Asia Minor) becomes a Roman province
# Number: 45
# math: the sixth positive integer with a prime factorization of the form p2q, with p and q being prime
# year: Galba becomes the commander of Legio III Augusta
# Number: 999
# math: the smallest number with the property that its first 55 multiples contain the digit 9
# year: Gerbert of Aurillac becomes Pope Silvester II and succeeds Pope Gregory V as the 139th pope
# Number: 1883
# math: the number of conjugacy classes of the alternating group A_{28}
# year: Otto von Bismarck pushes the first social security law through the Reichstag
